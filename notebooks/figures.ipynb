# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-3, 3, 0.01)
y = (1/np.sqrt(2*np.pi))*np.exp(-x**2/2)
fig, ax = plt.subplots(figsize=(15, 10))
ax.plot(x, y, 'k', lw=3)
ax.axis('off')
# Out:
# (-3.2994999999999934,
#  3.2894999999998658,
#  -0.01529367318753673,
#  0.4186678020009074)

# %%
fig.savefig("normal_curve.png", bbox_inches='tight')
